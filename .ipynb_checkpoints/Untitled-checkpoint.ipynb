# %%
import pandas as pd

# %%
df = pd.read_excel("all_1nm_data.xls")

# %%
df
# Out:
#     Note that not all data span the same wavelength range. Unnamed: 1  \
# 0              V(l) is identical to the 2° y bar data.            NaN
# 1                                                  NaN            NaN
# 2                                                   nm          CIE A
# 3                                                  300       0.930483
# 4                                                  301       0.967643
# 5                                                  302        1.00597
# 6                                                  303        1.04549
# 7                                                  304        1.08623
# 8                                                  305        1.12821
# 9                                                  306        1.17147
# 10                                                 307        1.21602
# 11                                                 308        1.26188
# ...
